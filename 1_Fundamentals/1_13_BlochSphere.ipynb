# %% [markdown]
# ## Qiskit Fundamentals
# ### 1.12 Measurement

# %%
import numpy as np
from qiskit.visualization import plot_bloch_vector

# %%
# Plot an arbitrary vector on the Bloch sphere:
plot_bloch_vector([0,1,0], title="Example Bloch Sphere")

# %%
# Use spherical coordinates instead of cartesian:
plot_bloch_vector([1, np.pi/2, np.pi/3], coord_type='spherical')
